# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import matplotlib.pyplot as plt

# %%
#setting style
plt.style.use('classic')

# %%
#ploting from the s
x=np.linspace(0,10,50)
print(x)
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x))
plt.show()
# Out:
# [ 0.          0.20408163  0.40816327  0.6122449   0.81632653  1.02040816
#   1.2244898   1.42857143  1.63265306  1.83673469  2.04081633  2.24489796
#   2.44897959  2.65306122  2.85714286  3.06122449  3.26530612  3.46938776
#   3.67346939  3.87755102  4.08163265  4.28571429  4.48979592  4.69387755
#   4.89795918  5.10204082  5.30612245  5.51020408  5.71428571  5.91836735
#   6.12244898  6.32653061  6.53061224  6.73469388  6.93877551  7.14285714
#   7.34693878  7.55102041  7.75510204  7.95918367  8.16326531  8.36734694
#   8.57142857  8.7755102   8.97959184  9.18367347  9.3877551   9.59183673
#   9.79591837 10.        ]

# %%
# %matplotlib
#matplotlib backend:Tkagg
# Out:
# Using matplotlib backend: Qt5Agg

# %%
x=np.linspace(0,10,20)
fig=plt.figure()
plt.plot(x,np.sin(x),'-')
plt.plot(x,np.cos(x),'+')

# %%
#saving the figure in the file
fig.savefig('my_figu.png')

# %%
from IPython.display import Image
Image('my_figu.png')

# %%
from IPython.display import Image
Image('my_figu.png')

# %%
#matlab style interface
plt.figure()
plt.subplot(2,1,1)
plt.plot(x,np.sin(x))

# %%
#creat sub panel of the curve axis
plt.subplot(2,3,4)
plt.plot(x,np.cos(x))
# Out:
# C:\Users\Raghav Jha\Anaco\lib\site-packages\ipykernel_launcher.py:2: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
#object orien tinterface
#ax wil two arry of an axis

fig,ax=plt.subplot(3)
ax[0].plot(x,np=sin(x))
ax[1].plot(x,np.cos(x));
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-c26ddcebc81d> in <module>
#       2 #ax wil two arry of an axis
#       3
# ----> 4 fig,ax=plt.subplot(3)
#       5 ax[0].plot(x,np=sin(x))
#       6 ax[1].plot(x,np.cos(x));
#
# ~\Anaco\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1074
#    1075     fig = gcf()
# -> 1076     a = fig.add_subplot(*args, **kwargs)
#    1077     bbox = a.bbox
#    1078     byebye = []
#
# ~\Anaco\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1380             if not 100 <= args[0] <= 999:
#    1381                 raise ValueError("Integer subplot specification must be a "
# -> 1382                                  "three-digit number, not {}".format(args[0]))
#    1383             args = tuple(map(int, str(args[0])))
#    1384
#
# ...

# %%
fig, ax = plt.subplots(2)
 # Call plot() method on the appropriate object
    ax[0].plot(x,np=sin(x))
ax[1].plot(x,np.cos(x));
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x));

# %%
fig, ax = plt.subplots(2)
fig, ax= plt.subplot(2)
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x));

# %%
fig, ax = plt.subplots(2)
ax[0].plot(x,np.sin(x))
ax[1].plot(x,np.cos(x));

# %%
#fig,a=plt.subplot(2)
fig,ax=plt.subplots(2)
ax[0].plot(x,np.sin(x))
ax[1].plot(x,np.cos(x));

# %%
#plotti4ing line by line
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
fig=plt.figure()
ax=plt.axes()
#import numpy as np

# %%
#ploting line by line
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
fig=plt.figure()
ax=plt.axes()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
fig=plt.figure()
ax=plt.axes()

# %%
fig=plt.figure()
ax=plt.axes()
np.linspace(0,20,30)
ax.plot(x,np.sin(x));

# %%
plt.plot(x,np.sin(x));

# %%
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x));

# %%
plt.plot(x, np.sin(x - 0), color='blue') # specify color by name
plt.plot(x, np.sin(x - 1), color='g') # short color code (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75') # Grayscale between 0 and 1
plt.plot(x, np.sin(x - 3), color='#FFDD44') # Hex code (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB tuple, values 0 and 1
plt.plot(x, np.sin(x - 5), color='chartreuse');

# %%
plt.plot(x,np.sin(x-0),color='blue')#specfic the color name
plt.plot(x,np.sin(x-1),color='g')#short color code
plt.plot(x,np.sin(x-1),color='0.75')#grayscale between 0 and 1
plt.plot(x,np.sin(x-4),color='#FFDD44')#hex code (rrgbbb from 0 to 1)
plt.plot(x,np.sin(x-5),color='cartreuse')
plt.plot(x,np.sin(x-5),color(1.0,.2,0.3));
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-114-52df5b935867> in <module>
#       4 plt.plot(x,np.sin(x-4),color='#FFDD44')#hex code (rrgbbb from 0 to 1)
#       5 plt.plot(x,np.sin(x-5),color='cartreuse')
# ----> 6 plt.plot(x,np.sin(x-5),color(1.0,2.0,0.3));
#
# NameError: name 'color' is not defined
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x010EF8E8> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaco\lib\site-packages\matplotlib\pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# ...

# %%
#line style keyword
plt.plot(x,x+0,linestyle='solid')
plt.plot(x,x+1,linestyle='dashed')
plt.plot(x,x+1, linestyle='dashdot')
plt.plot(x,x+3,linestyle='dotted');

# %%
plt.plot(x,x+0,linestyle='solid')
plt.plot(x,x+1,linestyle='dashed')
plt.plot(x,x+2,linestyle='dashdot')
plt.plot(x,x+3,linestyle='dotted');

# %%
#for the code
plt.plot(x,x+0,linestyle='-')
plt.plot(x,x+1,linestyle='--')
plt.plot(x,x+2,linestyle='-.')
plt.plot(x,x+3,linestyle=':');
plt.plot(x, x + 0, '-g') # solid green
plt.plot(x, x + 1, '--c') # dashed cyan
plt.plot(x, x + 2, '-.k') # dashdot black
plt.plot(x, x + 3, ':r');

# %%
plt.plot(x,x+0,'-g')#dashed green
plt.plot(x,x+1,'--c')#dashedcyaan
plt.plot(x,x+2,'-.k')#black
plt.plot(x,x+3,':r');#dot red

# %%
#adjusting the plot axes limit
plt.plot(x,np.sin(x))
plt.xlim(-1,11)
plt.ylim(-1.5,1.5)
# Out:
# (-1.5, 1.5)

# %%
plt.plot(x,np.sin(x))
plt.xlim(-1,11)
plt.ylim(-1.5,1.5)
# Out:
# (-1.5, 1.5)

# %%
#display the graph reverse
plt.plot(x,np.sin(x))
plt.axis('equal');

# %%
#labbling a graph 
plt.plot(x,np.sin(x))
plt.title('a sine curbe')
plt.xlabel('x')
plt.ylabel('sin(x)');

# %%
x=np.linspace(0,10,20)
y=np.sin(x)
plt.plot(x,y,'o',color='black');

# %%
rng=np.random.RandomState(0)
for marker in ['0','<','>','x','v','w','s','D','b']:
    plt.plot(rng.rand(5),rng.rand(5),marker,label='marker={0}'.format(marker))
    plt.legand(numpoints=1)
    plt.xlim(0,1.8);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-137-2af89160fd46> in <module>
#       1 rng=np.random.RandomState(0)
#       2 for marker in ['0','<','>','x','v','w','s','D','b']:
# ----> 3     plt.plot(rng.rand(5),rng.rand(5),marker,label='marker={0}'.format(marker))
#       4     plt.legand(numpoints=1)
#       5     plt.xlim(0,1.8);
#
# ~\Anaco\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2793     return gca().plot(
#    2794         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2795         is not None else {}), **kwargs)
#    2796
#    2797
#
# ~\Anaco\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# ...
